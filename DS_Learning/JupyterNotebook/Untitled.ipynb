# %%
import pandas as pd

# %%
data = pd.read_csv("../DATAANALYSIS/src/assets/input/data.csv")

# %%
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*         START*  \
# 0      11/6/2016 10:50   11/6/2016 11:04  Business          Agnew
# 1      11/5/2016 19:20   11/5/2016 19:28  Business          Agnew
# 2      11/4/2016 21:04   11/4/2016 21:20  Business          Agnew
# 3       11/5/2016 8:34    11/5/2016 8:43  Business          Agnew
# 4     10/30/2016 12:58  10/30/2016 13:18  Business         Almond
# ...                ...               ...       ...            ...
# 1151   11/2/2016 15:10   11/2/2016 15:18  Business    Whitebridge
# 1152    2/26/2016 9:06    2/26/2016 9:29  Business    Whitebridge
# 1153   7/21/2016 17:17   7/21/2016 17:23  Business    Whitebridge
# 1154  10/28/2016 18:13  10/28/2016 20:07  Business  Winston Salem
# 1155            Totals               NaN       NaN            NaN
#
#                STOP*   MILES* PURPOSE*
# 0        Renaissance      2.4      NaN
# 1              Agnew      2.2      NaN
# 2               Cory      4.3      NaN
# ...
